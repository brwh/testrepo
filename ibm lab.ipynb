# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Brad
# Machine Learning

# %% [markdown]
# *I am interested in data science because I would like to pursue a career in machine learning, and also apply my great communication skills acquired through my years of working in IT.

# %% [markdown]
# ### The code below will print out "I love data science"

# %%
print("I love data science")
# Out:
# I love data science

# %% [markdown]
# horizontal line below
# ***
#
# * These
# * Are
# * Bullets
#
# 1. These
# 1. Are
# 1. Numbered
# 1. Lists
